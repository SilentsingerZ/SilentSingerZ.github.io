# %%
import pandas as pd
import numpy as np
import csv
import string
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
dfDirty = pd.read_csv("https://raw.githubusercontent.com/INFO-4602-5602/project-2-ncwit-team-4/master/Submission/data/Hathaway/race_major.csv",low_memory=False)
dfDirty
# Out:
#     Unnamed: 0                 Major Program Name   Asian  \
# 0            0              Aerospace Engineering    36.0
# 1            1                     Bioinformatics     1.0
# 2            2             Biosystems Engineering     3.0
# 3            3               Chemical Engineering     9.0
# 4            4                  Civil Engineering    17.0
# 5            5                   Computer Science  1225.0
# 6            6               Computer Science + X  1214.0
# 7            7                      Cybersecurity     2.0
# 8            8   Electrcal & Computer Engineering     1.0
# 9            9             Electrical Engineering    28.0
# 10          10             Engineering Technology     4.0
# 11          11                        Game Design     3.0
# 12          12                General Engineering     3.0
# 13          13               General Engineering      2.0
# 14          14                Information Science   165.0
# 15          15               Information Science      0.0
# 16          16     Management Information Systems     8.0
# 17          17  Materials Science and Engineering     1.0
# 18          18             Mechanical Engineering    50.0
# 19          19               Software Engineering     0.0
# 20          20                Systems Engineering     0.0
#
#     Native Hawaiian/Other Pacific Islander   White  African American  \
# 0                                      1.0   144.0               7.0
# 1                                      0.0     3.0               0.0
# 2                                      0.0    42.0               2.0
# 3                                      0.0   144.0               8.0
# 4                                      1.0   134.0              44.0
# 5                                     19.0  1535.0             407.0
# 6                                      6.0   759.0             131.0
# 7                                      0.0     8.0               5.0
# 8                                      0.0     8.0               2.0
# 9                                      0.0   140.0              29.0
# 10                                     0.0    51.0               3.0
# 11                                     0.0    41.0               5.0
# 12                                     0.0    92.0               2.0
# 13                                     0.0    42.0               0.0
# 14                                     1.0   234.0              94.0
# 15                                     0.0     0.0               0.0
# 16                                     0.0    21.0              16.0
# 17                                     0.0     5.0               0.0
# 18                                     3.0   614.0              60.0
# 19                                     0.0     8.0               0.0
# 20                                     0.0    13.0               6.0
#
#     Hispanics  American Indian/Alaska Native
# 0        45.0                            3.0
# 1         0.0                            0.0
# 2         0.0                            0.0
# 3        11.0                            1.0
# 4      1391.0                            5.0
# 5      1790.0                           21.0
# 6      1589.0                           10.0
# 7         9.0                            0.0
# 8        76.0                            0.0
# 9        20.0                            3.0
# 10       17.0                            0.0
# 11        7.0                            0.0
# 12        5.0                            0.0
# 13        4.0                            0.0
# 14       71.0                            1.0
# 15        0.0                            0.0
# 16        1.0                            0.0
# 17        0.0                            0.0
# 18       81.0                            5.0
# 19        2.0                            0.0
# 20        3.0                            0.0

# %%
dfMajor = dfDirty[['Asian','Native Hawaiian/Other Pacific Islander','White','African American','Hispanics','American Indian/Alaska Native']]
dfMajor.reset_index(drop=True)
dfMajor.head()
# Out:
#    Asian  Native Hawaiian/Other Pacific Islander  White  African American  \
# 0   36.0                                     1.0  144.0               7.0
# 1    1.0                                     0.0    3.0               0.0
# 2    3.0                                     0.0   42.0               2.0
# 3    9.0                                     0.0  144.0               8.0
# 4   17.0                                     1.0  134.0              44.0
#
#    Hispanics  American Indian/Alaska Native
# 0       45.0                            3.0
# 1        0.0                            0.0
# 2        0.0                            0.0
# 3       11.0                            1.0
# 4     1391.0                            5.0

# %%
def automajor(major):
    labels = 'Asian', 'Native Hawaiian', 'White', 'African American', 'Hispanics', 'American Indian/Alaska Native'
    colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'pink', 'red']
    explode = (0.1, 0, 0, 0, 0, 0)  # explode 1st slice
    #sizes = dfM[dfM['Major Program Name']==major].values.tolist()
    sizes = dfMajor.iloc[major].values.tolist()
    
    plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
    #plt.title("Percentage of each race in %s" %major)
    plt.axis('equal')

# %%
automajor(10)
